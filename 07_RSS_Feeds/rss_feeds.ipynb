# %% [markdown]
# # Getting Text data from RSS-Feeds

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import feedparser
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /workspaces/data_ingestion/07_RSS_Feeds

# %% [markdown]
# ## Parse the RSS feed

# %%
# RSS feeds from NZZ website
feed = feedparser.parse("https://www.nzz.ch/startseite.rss")

# %% [markdown]
# ## Extract the data

# %%
# Get data from RSS feeds
feed_entries = feed.entries

# Initialize an empty string to store the text
wordcloud_text = ""

# Show first RSS-feeds
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title
    article_link = entry.link
    article_published_at = entry.published
    article_published_at_parsed = entry.published_parsed

    # Append the title to the wordcloud_text
    wordcloud_text += f"{article_title} "

    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")
# Out:
# Article Titles:
# Der Wunsch nach dem starken Mann: Donald Trumps grosser Wahlsieg läutet eine neue Zeit ein
# American Heartbreak: Was Trumps Rückkehr mit unserem Bild von Amerika macht
# Trump vervollständigt seinen Sieg und gewinnt auch noch die letzten beiden Swing States – alle Resultate in der Übersicht
# INTERVIEW - «Nordkorea hat den Stalinismus perfektioniert»: Südkoreas frühere Aussenministerin über den schwierigen Konflikt mit dem nördlichen Nachbarn – und ihr Rat an Europa
# LIVE - Krieg in der Ukraine: Russland meldet Drohnenangriffe auf Moskau +++ Kiew will Treffen Selenskis mit Trump vorbereiten
# Wie premium ist Lindt-Schokolade? Die Firma sagt, die Marke Excellence sei bloss «übertriebene Werbung, auf die sich kein Konsument verlasse»
# Wäre Boris Pistorius der bessere Kanzler als Olaf Scholz? Die SPD sagt: Nein. «Wir machen ja auch nicht Thomas Gottschalk oder Günther Jauch zum Kandidaten»
# Die Geschichte eines Genfer Elternpaars, das die Obhut für sein 15-jähriges Kind verlor, weil es sich gegen eine Geschlechtsumwandlung stemmte
# INTERVIEW - «Ich bin halt ein relativ cooler Typ»: Xherdan Shaqiri sagt, warum man ihn gernhat und wie er über eine Rückkehr in die Nati denkt
# Trump und Musk telefonieren mit Selenski
# Die europäischen Rechtspopulisten feiern das Comeback von Trump – nur Marine Le Pen reagiert zurückhaltend
# Kampf um das Abtreibungsrecht: Die Resultate in konservativen Gliedstaaten verblüffen
# BILDSTRECKE - Donald Trumps Comeback: sein Weg von Queens bis zur Wiederwahl in Bildern
# Die Republikaner haben nun auch die Mehrheit im Senat
# An den Finanzmärkten beginnen sich die Trump-Trades für die Investoren auszuzahlen
# «Es fallen viele Kraftausdrücke, wenn die Leute auf Donald Trump zu sprechen kommen»: So erlebten unsere Korrespondenten die Wahlnacht
# Mehr deutsche Waffen für die Ukraine? Wenn die Bundeswehr doch nur welche hätte
# Ziemlich beste Freunde? Donald Trump und Elon Musk wirken unzertrennlich. Der Eindruck könnte täuschen
# AUS DEM ORBIT - Satellitenbild löst jahrzehntealtes Rätsel um vermissten Mann in Florida
# China, Nahost, Wirtschaft: was Trumps Wahlsieg für die Welt bedeutet
# NZZ FORMAT - Abgestumpft vom Weltchaos? – Was die Flut der Schreckensmeldungen mit uns macht
# Angst ist das Gespenst der Gegenwart
# «Ich hatte eine wirklich schöne und idyllische Kindheit in Auschwitz», sagt der Sohn von Rudolf Höss, einem der schlimmsten Massenmörder
# «Bin ich weg, gibt’s eine CO2-Schleuder weniger»: Im Kieler «Tatort» steigen Klimaaktivisten freiwillig in die eisigen Fluten. Oder treibt jemand die Jugendlichen in den Tod?
# BILDSTRECKE - 35 Jahre nach dem Mauerfall: Neun  Fotografinnen und Fotografen zeigen ihren Blick auf das Berlin der 1990er Jahre
# KOLUMNE - «Ich fühle mich heute etwas depressiv»
# «Wenn Sie merken, es kommen trübe Gedanken, setzen Sie sich auf Ihren Grübelstuhl, und lassen Sie das Gedankenkreisen zu»
# Newsletter «Wohl & Sein»: Hintergründe über Ernährung, Gesundheit und Psychologie – jeden Donnerstag in Ihrem Postfach.
# FREIZEITSPORT - Bergauf und bergab joggen ist sinnvoll – so funktioniert es
# «Generation Angst»: Der Einfluss sozialer Netzwerke auf die Jugend wird überschätzt
# KURZ ERKLÄRT - Naturejoghurt, griechisches Joghurt oder Skyr: Was ist am gesündesten?
# ERKLÄRT - Wie kann ich meine Erkältung lindern? Sieben Tipps im Faktencheck
# Ob der Chef oder die eigene Mutter: Viele Menschen übernehmen keine Verantwortung für ihr Fehlverhalten. Wie man ihre manipulative Taktik erkennt
# Von der Panoramastrasse zum atombombensicheren Bunker – was die erste Autobahn über die Schweiz erzählt
# Deutschland ringt um einen Termin für die Neuwahlen: Wer aufs Gas drückt – und wer auf die Bremse tritt
# INTERVIEW - «Weder gab Trump den Bundesräten Spitznamen, noch klopfte er Sprüche»
# GASTKOMMENTAR - Hegemoniale Vorherrschaft muss sein – die gefährlichen weltpolitischen Theorien des «offensiven Realisten» John Mearsheimer
# KOMMENTAR - Regierungs-Aus in Deutschland: Olaf Scholz’ schäbiges Spiel
# DER ANDERE BLICK - Nach dem Scheitern der Regierung Scholz muss das bürgerliche Lager liefern. Es ist seine letzte Chance
# Trumps dreifacher Triumph: Zum Weissen Haus kommt wohl die Mehrheit in beiden Kammern des Kongresses hinzu
# Auf die Korruption folgt das Chaos: Die Regierung von Moçambique flüchtet nach Ausschreitungen in den Norden
# INTERVIEW - «Wir verkaufen keine Birkin-Bags an Leute, die damit nur Geld machen wollen»
# Ein Franzose hat mit Wetten auf einen Sieg Trumps 85 Millionen Dollar Gewinn erzielt
# Er hatte die Idee, das grosse Geld machten andere: Philippe Kohlbrenner erfand das Traditions-E-Bike Flyer – und ging vergessen
# Unheimliche Dominanz: US-Aktien sind stärker gestiegen als alle anderen – sind wir in einer Blase?
# «Die derzeit geltenden Ziele sind keine Ambition mehr für uns», sagt die Zurich-Finanzchefin Claudia Cordioli
# Für Swiss Re ist die Inflation nicht besiegt. Der Rückversicherer polstert sich mit Milliarden gegen die Klageflut in den USA
# Viola Amherd will die Schuldenbremse lockern
# Abstimmungskampf zur Gesundheitsreform: fragwürdige Behauptungen zu den Krankenkassenprämien
# 12 Jahre nach dem Atomausstieg: Die SVP Winterthur will, dass die Stadt Atomstrom anbietet – und ihn als klimafreundlich verkauft
# «Etikettenschwindel» oder «wichtiges Massnahmenpaket» – die beiden Vorlagen zu bezahlbarem Wohnraum in der Stadt Zürich im Überblick
# 2026 wird das Grossmünster vollständig eingepackt – Zürichs 800 Jahre altes Wahrzeichen braucht eine Auffrischung
# Neue Hoffnungen: Rettet Bernhard Russi den Ski-Weltcup in Zermatt?
# Tadej Pogacar: Der weltbeste Radprofi und sein Geheimnis
# Ein Schweizer Trio startet am Sonntag zum härtesten Segelrennen der Welt: Es weckt Erinnerungen an schillernde Seebären
# Der Hanser-Verlag verzichtet auf sein intellektuelles Schlachtschiff
# Mit ihren Prognosen zum US-Wahlausgang lagen die meisten Medien falsch, Kamala Harris wurde stärker gemacht, als sie war. Nun sollen andere an ihrer Niederlage schuld sein
# Dichten, was das Zeug hält. Oswald Eggers Werk entsteht zwischen Poesie und Philosophie und macht den Leser schwindlig vor Glück
# Die Kopfhörer von Apple funktionieren jetzt auch als Hörgerät. Das ist eine Chance für alle mit leichten Hörschäden
# Amerikanische Tech-Giganten investieren Millionen in kleine Kernreaktoren. Was versprechen sie sich davon?
# «Wir sind schockiert!»: Junge Wissenschafterinnen setzen die ETH Zürich wegen Mobbings und Übergriffen unter Druck

# %% [markdown]
# ## Generate a WordCloud

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-10 12:45:05
# Python Version: 3.11.10
# -----------------------------------
